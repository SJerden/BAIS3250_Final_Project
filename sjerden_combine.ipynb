# %%
import pandas as pd

# %%
cars_2022 = pd.read_csv("kaggle_cars_cleaned.csv")
cars_2025 = pd.read_csv("cars_scraped_cleaned.csv")

# %%
cars_all = pd.concat([cars_2022, cars_2025])

# %%
cars_all
# Out:
#       Unnamed: 0          brand                                 model  \
# 0              0           Ford       Utility Police Interceptor Base
# 1              1        Hyundai                          Palisade SEL
# 2              2          Lexus                         RX 350 RX 350
# 3              3       INFINITI                      Q50 Hybrid Sport
# 4              4           Audi             Q3 45 S line Premium Plus
# ...          ...            ...                                   ...
# 4007        4007           Ford                          F-150 Raptor
# 4008        4008            BMW                          X3 xDrive30i
# 0              0          Mazda  CX-50 2.5 Turbo Premium Plus Package
# 1              1  Mercedes-Benz               AMG GLC 43 4MATIC Coupe
# 2              2         Toyota   Grand Highlander Hybrid Limited MAX
#
#       model_year      fuel_type  \
# 0           2013  E85 Flex Fuel
# 1           2021       Gasoline
# ...

# %%
cars_all.to_csv("sjerden_integrated_data_proposal.csv")
