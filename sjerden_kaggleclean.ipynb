# %%
import pandas as pd

# %%
used_cars = pd.read_csv("used_cars.csv")
used_cars
# Out:
#          brand                            model  model_year      milage  \
# 0         Ford  Utility Police Interceptor Base        2013  51,000 mi.
# 1      Hyundai                     Palisade SEL        2021  34,742 mi.
# 2        Lexus                    RX 350 RX 350        2022  22,372 mi.
# 3     INFINITI                 Q50 Hybrid Sport        2015  88,900 mi.
# 4         Audi        Q3 45 S line Premium Plus        2021   9,835 mi.
# ...        ...                              ...         ...         ...
# 4004   Bentley             Continental GT Speed        2023     714 mi.
# 4005      Audi             S4 3.0T Premium Plus        2022  10,900 mi.
# 4006   Porsche                           Taycan        2022   2,116 mi.
# 4007      Ford                     F-150 Raptor        2020  33,000 mi.
# 4008       BMW                     X3 xDrive30i        2020  43,000 mi.
#
#           fuel_type                                             engine  \
# ...

# %%
used_cars.isna().sum()
# Out:
# brand             0
# model             0
# model_year        0
# milage            0
# fuel_type       170
# engine            0
# transmission      0
# ext_col           0
# int_col           0
# accident        113
# clean_title     596
# price             0
# dtype: int64

# %% [markdown]
# ### Modifying data types so that data can be used for calculations later

# %%
used_cars['new_price'] = used_cars['price'].str.replace("$","").str.replace(",","")
used_cars['new_price'] = used_cars['new_price'].astype("int")

# %%
used_cars['new_mileage'] = used_cars['milage'].str.replace("mi.","").str.replace(",","")
used_cars['new_mileage'] = used_cars['new_mileage'].astype("int")

# %%
used_cars['new_accident'] = used_cars['accident'].str.replace("None reported", "False").str.replace("At least 1 accident or damage reported", "True")
used_cars['new_accident'].astype("bool")
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 4004    True
# 4005    True
# 4006    True
# 4007    True
# 4008    True
# Name: new_accident, Length: 4009, dtype: bool

# %%
used_cars
# Out:
#          brand                            model  model_year      milage  \
# 0         Ford  Utility Police Interceptor Base        2013  51,000 mi.
# 1      Hyundai                     Palisade SEL        2021  34,742 mi.
# 2        Lexus                    RX 350 RX 350        2022  22,372 mi.
# 3     INFINITI                 Q50 Hybrid Sport        2015  88,900 mi.
# 4         Audi        Q3 45 S line Premium Plus        2021   9,835 mi.
# ...        ...                              ...         ...         ...
# 4004   Bentley             Continental GT Speed        2023     714 mi.
# 4005      Audi             S4 3.0T Premium Plus        2022  10,900 mi.
# 4006   Porsche                           Taycan        2022   2,116 mi.
# 4007      Ford                     F-150 Raptor        2020  33,000 mi.
# 4008       BMW                     X3 xDrive30i        2020  43,000 mi.
#
#           fuel_type                                             engine  \
# ...

# %% [markdown]
# ### Dropping redundant rows and renaming columns to match their predecessors

# %%
used_cars = used_cars.drop(['milage','price', 'accident'], axis=1)

# %%
used_cars = used_cars.rename(columns={
    'new_price': 'price',
    'new_mileage': 'mileage',
    'new_accident': 'accident'
})

# %%
used_cars
# Out:
#          brand                            model  model_year      fuel_type  \
# 0         Ford  Utility Police Interceptor Base        2013  E85 Flex Fuel
# 1      Hyundai                     Palisade SEL        2021       Gasoline
# 2        Lexus                    RX 350 RX 350        2022       Gasoline
# 3     INFINITI                 Q50 Hybrid Sport        2015         Hybrid
# 4         Audi        Q3 45 S line Premium Plus        2021       Gasoline
# ...        ...                              ...         ...            ...
# 4004   Bentley             Continental GT Speed        2023       Gasoline
# 4005      Audi             S4 3.0T Premium Plus        2022       Gasoline
# 4006   Porsche                           Taycan        2022            NaN
# 4007      Ford                     F-150 Raptor        2020       Gasoline
# 4008       BMW                     X3 xDrive30i        2020       Gasoline
#
#                                                  engine  \
# ...

# %%
used_cars.to_csv("kaggle_cars_cleaned.csv")
